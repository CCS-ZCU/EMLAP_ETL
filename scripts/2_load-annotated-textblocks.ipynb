# %%
import os
import json

# %%
source_path = "/srv/data/tome/tome-corpus/emlap_annotated_textblocks/"
len(os.listdir(source_path))
# Out:
# 118

# %%
filename = 'DuChesne1575_Ad_Iacobi_Auberti_MDZ_Augsburg.json'
filepath = os.path.join(source_path, filename)
with open(filepath, 'r', encoding='utf-8') as f:
    textblocks = json.load(f)

# %%
textblocks[1:3]
# Out:
# [[{'coordinates': [75.5999984741211,
#     92.16000366210938,
#     419.6839904785156,
#     96.95999908447266],
#    'text': 'AD IACOBI\n',
#    'tag': 'title'},
#   {'coordinates': [85.91999816894531,
#     128.63998413085938,
#     411.876220703125,
#     133.4399871826172],
#    'text': 'AVBERTI VINDO¬\n',
#    'tag': 'text'},
#   {'coordinates': [99.83999633789062,
#     158.90396118164062,
#     398.69488525390625,
#     163.82395935058594],
#    'text': 'NIS DE ORTV ET CAVSIS\n',
#    'tag': 'text'},
#   {'coordinates': [120.95999908447266,
#     186.98397827148438,
#     384.4850158691406,
#     191.9039764404297],
#    'text': 'METALLORVM CONTRA\n',
#    'tag': 'text'},
#   {'coordinates': [161.27999877929688,
#     205.19998168945312,
#     341.8544006347656,
#     209.99998474121094],
#    'text': 'Chymicos Explicationem\n',
#    'tag': 'text'},
#   {'coordinates': [74.16000366210938,
#     242.87997436523438,
#     418.4440612792969,
#     247.6799774169922],
#    'text': 'IOSEPHI QVERCETANI ARME¬\n',
#    'tag': 'text'},
#   {'coordinates': [134.16000366210938,
#     264.2640075683594,
#     368.1369323730469,
#     269.18402099609375],
#    'text': 'niaci, D. Medici breuis Responsio.\n',
#    'tag': 'text'},
#   {'coordinates': [75.12000274658203,
#     298.1039733886719,
#     427.63800048828125,
#     303.02398681640625],
#    'text': 'EIVSDEM DE EXQVISITA\n',
#    'tag': 'text'},
#   {'coordinates': [98.4000015258789,
#     315.1439514160156,
#     402.23760986328125,
#     320.06396484375],
#    'text': 'Mineralium, Animalium, & Vegetabilium me¬\n',
#    'tag': 'text'},
#   {'coordinates': [130.55999755859375,
#     332.8799743652344,
#     367.60992431640625,
#     337.6799621582031],
#    'text': 'dicamentorum Spagyrica praeparatione &\n',
#    'tag': 'text'},
#   {'coordinates': [174.0,
#     348.9599914550781,
#     318.1943054199219,
#     353.7599792480469],
#    'text': 'vsu, perspicua Tractatio.\n',
#    'tag': 'text'},
#   {'coordinates': [171.83999633789062,
#     650.8799438476562,
#     315.4711608886719,
#     655.6799926757812],
#    'text': 'LVGDVNI,\n',
#    'tag': 'text'},
#   {'coordinates': [114.95999908447266,
#     677.0640258789062,
#     371.6669616699219,
#     681.9840087890625],
#    'text': 'Apud loannem Lertotium.\n',
#    'tag': 'text'},
#   {'coordinates': [168.0,
#     712.8240356445312,
#     319.2654113769531,
#     717.7440185546875],
#    'text': 'M. D. LXXV.\n',
#    'tag': 'text'}],
#  [{'coordinates': [260.1600036621094,
#     246.72000122070312,
#     432.2148132324219,
#     251.52000427246094],
#    'text': 'QVADRIN.\n',
#    'tag': 'header'},
#   {'coordinates': [173.75999450683594,
#     284.6399841308594,
#     475.51812744140625,
#     289.4399719238281],
#    'text': '[F] En nostre estat au vostre tout contraire,\n',
#    'tag': 'text'},
#   {'coordinates': [192.0,
#     310.5599670410156,
#     521.3158569335938,
#     315.3599548339844],
#    'text': "Si nous soufflons, vous humez d'autrepart:\n",
#    'tag': 'text'},
#   {'coordinates': [190.0800018310547,
#     335.03997802734375,
#     507.86492919921875,
#     339.8399658203125],
#    'text': "Or sus enfans, de ces deux poincts de l'art,\n",
#    'tag': 'text'},
#   {'coordinates': [190.32000732421875,
#     358.55999755859375,
#     470.3236389160156,
#     363.3599853515625],
#    'text': 'Iugez lequel est plus seant de faire. [/F]\n',
#    'tag': 'text'},
#   {'coordinates': [199.67999267578125,
#     402.9839782714844,
#     476.27587890625,
#     407.90399169921875],
#    'text': 'VIRTVTIS COMES\n',
#    'tag': 'text'},
#   {'coordinates': [268.79998779296875,
#     428.15997314453125,
#     419.5696105957031,
#     432.9599609375],
#    'text': 'INVIDIA.\n',
#    'tag': 'text'}]]

# %%
for p in textblocks:
    for tb in p:
        if tb["tag"] in ["text"]:
